# %%
import requests
import yaml
import json
import time

TARGET_URL = "https://sudomaze.dev"
BASE_URL = "https://www.googleapis.com/pagespeedonline/v5/runPagespeed"
PATHS = ['/','/about','/notes','/projects','/cv','/site']
CATEGORIES = ["accessibility", "best-practices", "performance", "pwa", "seo"]

# get the dynamic pages
# r_urls = json.loads(requests.get("https://sudomaze.dev/search.json").text)
# for i in range(len(r_urls)):
#     PATHS.append(r_urls[i]['url'])
sstart = time.time()
for path in PATHS:
    start = time.time()
    print(f'PATH: {path}')
    api_key = yaml.load(open('secret.yml'), Loader=yaml.FullLoader)['api']
    total_url_desktop = f'{BASE_URL}?url={TARGET_URL}{path}&key={api_key}&category={"&category=".join(CATEGORIES)}&strategy=desktop'
    total_url_mobile = f'{BASE_URL}?url={TARGET_URL}{path}&key={api_key}&category={"&category=".join(CATEGORIES)}&strategy=mobile'
    data_desktop = json.loads(requests.get(total_url_desktop).text)
    data_mobile = json.loads(requests.get(total_url_mobile).text)
    for category in data_desktop['lighthouseResult']['categories']:
        print(f"(DESKTOP) {category}: {data_desktop['lighthouseResult']['categories'][category]['score']}")
        print(f"(MOBILE) {category}: {data_mobile['lighthouseResult']['categories'][category]['score']}")
    end = time.time() - start
    print(f'TIME: {end}')
end = time.time() - sstart
print(end)
# Out:
# PATH: /
# (DESKTOP) performance: 0.99
# (MOBILE) performance: 0.93
# (DESKTOP) accessibility: 0.97
# (MOBILE) accessibility: 0.97
# (DESKTOP) best-practices: 1
# (MOBILE) best-practices: 1
# (DESKTOP) seo: 1
# (MOBILE) seo: 0.96
# (DESKTOP) pwa: 0.56
# (MOBILE) pwa: 0.57
# TIME: 17.897708654403687
# PATH: /about
# (DESKTOP) performance: 0.97
# (MOBILE) performance: 0.9
# (DESKTOP) accessibility: 0.86
# (MOBILE) accessibility: 0.84
# (DESKTOP) best-practices: 1
# (MOBILE) best-practices: 1
# (DESKTOP) seo: 1
# (MOBILE) seo: 0.96
# (DESKTOP) pwa: 0.56
# (MOBILE) pwa: 0.57
# TIME: 25.580965995788574
# PATH: /notes
# (DESKTOP) performance: 1
# (MOBILE) performance: 0.93
# (DESKTOP) accessibility: 1
# (MOBILE) accessibility: 1
# (DESKTOP) best-practices: 1
# (MOBILE) best-practices: 1
# (DESKTOP) seo: 1
# (MOBILE) seo: 0.97
# (DESKTOP) pwa: 0.56
# (MOBILE) pwa: 0.57
# TIME: 16.30385446548462
# PATH: /projects
# (DESKTOP) performance: 1
# (MOBILE) performance: 0.95
# (DESKTOP) accessibility: 1
# (MOBILE) accessibility: 1
# (DESKTOP) best-practices: 1
# (MOBILE) best-practices: 1
# (DESKTOP) seo: 1
# (MOBILE) seo: 0.97
# (DESKTOP) pwa: 0.56
# (MOBILE) pwa: 0.57
# TIME: 14.942329406738281
# PATH: /cv
# (DESKTOP) performance: 0.99
# (MOBILE) performance: 0.9
# (DESKTOP) accessibility: 0.97
# (MOBILE) accessibility: 0.95
# (DESKTOP) best-practices: 1
# (MOBILE) best-practices: 1
# (DESKTOP) seo: 1
# (MOBILE) seo: 0.96
# (DESKTOP) pwa: 0.56
# (MOBILE) pwa: 0.57
# TIME: 19.071476459503174
# PATH: /site
# (DESKTOP) performance: 0.99
# (MOBILE) performance: 0.93
# (DESKTOP) accessibility: 0.97
# (MOBILE) accessibility: 0.95
# (DESKTOP) best-practices: 1
# (MOBILE) best-practices: 1
# (DESKTOP) seo: 1
# (MOBILE) seo: 0.96
# (DESKTOP) pwa: 0.56
# (MOBILE) pwa: 0.57
# TIME: 18.83545207977295
# 112.6328866481781
